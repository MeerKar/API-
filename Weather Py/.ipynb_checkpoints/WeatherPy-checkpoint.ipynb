# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 651

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
        
# List for holding reponse information
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# Loop through the list of cities and request for data on each
print("Beginning Data Retrieval")
print("--------------------------------------------")
count = 0
set = 1
for idx, city in enumerate(cities):
    count = count + 1
    # To avoid api call rate limits, get city weather data for 50 cities,
    # then sleep for 5 seconds, and then continue with next 50 cities and so on...
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("------------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | tilichiki
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | mlonggo
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | brownsville
# Processing Record 12 of Set 1 | strezhevoy
# Processing Record 13 of Set 1 | mount isa
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | montepuez
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | vila velha
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | teguise
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | khorixas
# Processing Record 22 of Set 1 | ballina
# Processing Record 23 of Set 1 | ashdod
# Processing Record 24 of Set 1 | terrace
# Processing Record 25 of Set 1 | westport
# Processing Record 26 of Set 1 | agnibilekrou
# Processing Record 27 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 1 | opuwo
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | anyang
# Processing Record 31 of Set 1 | arrifes
# Processing Record 32 of Set 1 | segou
# Processing Record 33 of Set 1 | vuktyl
# Processing Record 34 of Set 1 | buchanan
# Processing Record 35 of Set 1 | gijon
# Processing Record 36 of Set 1 | san policarpo
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | achisay
# City not found. Skipping...
# Processing Record 39 of Set 1 | oranjestad
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | culpeper
# Processing Record 42 of Set 1 | rawson
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | yulara
# Processing Record 45 of Set 1 | barra do garcas
# Processing Record 46 of Set 1 | porto novo
# Processing Record 47 of Set 1 | itaituba
# Processing Record 48 of Set 1 | puerto real
# Processing Record 49 of Set 1 | mantua
# Processing Record 50 of Set 1 | manicore
# Processing Record 1 of Set 2 | playa vicente
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | pacific grove
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | constitucion
# Processing Record 9 of Set 2 | deputatskiy
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | norsup
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | brae
# Processing Record 15 of Set 2 | mandalgovi
# Processing Record 16 of Set 2 | sioux lookout
# Processing Record 17 of Set 2 | te anau
# Processing Record 18 of Set 2 | rundu
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | saint-georges
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | monastyrshchina
# Processing Record 26 of Set 2 | camacha
# Processing Record 27 of Set 2 | linxia
# Processing Record 28 of Set 2 | muzquiz
# City not found. Skipping...
# Processing Record 29 of Set 2 | tyrma
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | lingao
# Processing Record 34 of Set 2 | codrington
# Processing Record 35 of Set 2 | axim
# Processing Record 36 of Set 2 | puerto escondido
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | shakhtinsk
# Processing Record 39 of Set 2 | saint-joseph
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | boa vista
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | madang
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | maldonado
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | merauke
# Processing Record 2 of Set 3 | agen
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | sarkand
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | banagher
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | rocha
# Processing Record 11 of Set 3 | aksu
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | husavik
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | saint anthony
# Processing Record 18 of Set 3 | los llanos de aridane
# Processing Record 19 of Set 3 | poso
# Processing Record 20 of Set 3 | qarqin
# Processing Record 21 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 22 of Set 3 | akhtubinsk
# Processing Record 23 of Set 3 | belyy yar
# Processing Record 24 of Set 3 | erenhot
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | salinas
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | upernavik
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | hit
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | jawhar
# Processing Record 34 of Set 3 | ugoofaaru
# Processing Record 35 of Set 3 | neiafu
# Processing Record 36 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | pizarro
# Processing Record 38 of Set 3 | mogadishu
# Processing Record 39 of Set 3 | baykit
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 3 | conceicao do araguaia
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | basco
# Processing Record 45 of Set 3 | edd
# Processing Record 46 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 3 | namatanai
# Processing Record 48 of Set 3 | khuzdar
# Processing Record 49 of Set 3 | hasaki
# Processing Record 50 of Set 3 | lavrentiya
# Processing Record 1 of Set 4 | chumikan
# Processing Record 2 of Set 4 | gorontalo
# Processing Record 3 of Set 4 | bougouni
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | tucurui
# Processing Record 6 of Set 4 | baruun-urt
# Processing Record 7 of Set 4 | teya
# Processing Record 8 of Set 4 | ergolding
# Processing Record 9 of Set 4 | jonkoping
# Processing Record 10 of Set 4 | cayenne
# Processing Record 11 of Set 4 | eureka
# Processing Record 12 of Set 4 | beyneu
# Processing Record 13 of Set 4 | kidal
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | jamestown
# Processing Record 16 of Set 4 | svirstroy
# Processing Record 17 of Set 4 | mashhad
# Processing Record 18 of Set 4 | northam
# Processing Record 19 of Set 4 | igrim
# Processing Record 20 of Set 4 | ambon
# Processing Record 21 of Set 4 | salinopolis
# Processing Record 22 of Set 4 | sao filipe
# Processing Record 23 of Set 4 | cabedelo
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | dossor
# Processing Record 26 of Set 4 | vestmannaeyjar
# Processing Record 27 of Set 4 | jumla
# Processing Record 28 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 4 | katsuura
# Processing Record 30 of Set 4 | nikolskoye
# Processing Record 31 of Set 4 | dubai
# Processing Record 32 of Set 4 | kutum
# Processing Record 33 of Set 4 | antofagasta
# Processing Record 34 of Set 4 | weihai
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | tiznit
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | saldanha
# Processing Record 39 of Set 4 | steinbach
# Processing Record 40 of Set 4 | queanbeyan
# Processing Record 41 of Set 4 | medicine hat
# Processing Record 42 of Set 4 | tautira
# Processing Record 43 of Set 4 | yellowknife
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | cape town
# Processing Record 46 of Set 4 | harper
# Processing Record 47 of Set 4 | dombarovskiy
# Processing Record 48 of Set 4 | cartagena del chaira
# Processing Record 49 of Set 4 | dikson
# Processing Record 50 of Set 4 | makhu
# Processing Record 1 of Set 5 | omboue
# Processing Record 2 of Set 5 | palmer
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | estelle
# Processing Record 5 of Set 5 | nanortalik
# Processing Record 6 of Set 5 | port lincoln
# Processing Record 7 of Set 5 | aranos
# Processing Record 8 of Set 5 | nizwa
# Processing Record 9 of Set 5 | carnarvon
# Processing Record 10 of Set 5 | gizo
# Processing Record 11 of Set 5 | camopi
# Processing Record 12 of Set 5 | ushtobe
# Processing Record 13 of Set 5 | sobolevo
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | komsomolskiy
# Processing Record 16 of Set 5 | hammerfest
# Processing Record 17 of Set 5 | hanna
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | pendleton
# Processing Record 20 of Set 5 | faanui
# Processing Record 21 of Set 5 | maceio
# Processing Record 22 of Set 5 | san felipe
# Processing Record 23 of Set 5 | new richmond
# Processing Record 24 of Set 5 | tuyen quang
# Processing Record 25 of Set 5 | okhotsk
# Processing Record 26 of Set 5 | paamiut
# Processing Record 27 of Set 5 | blonduos
# City not found. Skipping...
# Processing Record 28 of Set 5 | nueva germania
# Processing Record 29 of Set 5 | kolokani
# Processing Record 30 of Set 5 | brewster
# Processing Record 31 of Set 5 | waingapu
# Processing Record 32 of Set 5 | khoy
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | alghero
# Processing Record 35 of Set 5 | kiruna
# Processing Record 36 of Set 5 | touros
# Processing Record 37 of Set 5 | vrangel
# Processing Record 38 of Set 5 | gravelbourg
# Processing Record 39 of Set 5 | karakol
# Processing Record 40 of Set 5 | ibimirim
# Processing Record 41 of Set 5 | kawambwa
# Processing Record 42 of Set 5 | bengkulu
# Processing Record 43 of Set 5 | halifax
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | penzance
# Processing Record 46 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 5 | sonoita
# Processing Record 48 of Set 5 | kuito
# Processing Record 49 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 5 | havre-saint-pierre
# Processing Record 1 of Set 6 | tuatapere
# Processing Record 2 of Set 6 | almansa
# Processing Record 3 of Set 6 | portland
# Processing Record 4 of Set 6 | ulagan
# Processing Record 5 of Set 6 | trincomalee
# Processing Record 6 of Set 6 | ende
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | clyde river
# Processing Record 9 of Set 6 | hilo
# Processing Record 10 of Set 6 | toungoo
# City not found. Skipping...
# Processing Record 11 of Set 6 | yatou
# Processing Record 12 of Set 6 | la libertad
# Processing Record 13 of Set 6 | trofors
# Processing Record 14 of Set 6 | salalah
# Processing Record 15 of Set 6 | severiano melo
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 6 | carbonia
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | qaqortoq
# Processing Record 22 of Set 6 | mabaruma
# Processing Record 23 of Set 6 | cap malheureux
# Processing Record 24 of Set 6 | nyagan
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | edson
# Processing Record 27 of Set 6 | janauba
# Processing Record 28 of Set 6 | oum hadjer
# Processing Record 29 of Set 6 | campbell river
# Processing Record 30 of Set 6 | pringsewu
# Processing Record 31 of Set 6 | sanandaj
# Processing Record 32 of Set 6 | atid
# Processing Record 33 of Set 6 | mizdah
# Processing Record 34 of Set 6 | quartucciu
# Processing Record 35 of Set 6 | spearfish
# Processing Record 36 of Set 6 | milkovo
# Processing Record 37 of Set 6 | bayanday
# Processing Record 38 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | plettenberg bay
# Processing Record 41 of Set 6 | lebu
# Processing Record 42 of Set 6 | ust-ishim
# Processing Record 43 of Set 6 | caravelas
# Processing Record 44 of Set 6 | mindelo
# Processing Record 45 of Set 6 | hambantota
# Processing Record 46 of Set 6 | bilibino
# Processing Record 47 of Set 6 | guerrero negro
# Processing Record 48 of Set 6 | bonavista
# Processing Record 49 of Set 6 | zyryanka
# Processing Record 50 of Set 6 | port blair
# Processing Record 1 of Set 7 | labuhan
# Processing Record 2 of Set 7 | poum
# Processing Record 3 of Set 7 | tura
# Processing Record 4 of Set 7 | chokurdakh
# Processing Record 5 of Set 7 | guadalupe y calvo
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | isangel
# Processing Record 8 of Set 7 | ocos
# Processing Record 9 of Set 7 | weligama
# Processing Record 10 of Set 7 | matamoros
# Processing Record 11 of Set 7 | leshukonskoye
# Processing Record 12 of Set 7 | norman
# Processing Record 13 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 7 | hualmay
# Processing Record 15 of Set 7 | broome
# Processing Record 16 of Set 7 | itarema
# Processing Record 17 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 7 | kaspiysk
# Processing Record 19 of Set 7 | la ronge
# Processing Record 20 of Set 7 | marawi
# Processing Record 21 of Set 7 | comodoro rivadavia
# Processing Record 22 of Set 7 | lahaina
# Processing Record 23 of Set 7 | yuci
# Processing Record 24 of Set 7 | mehamn
# Processing Record 25 of Set 7 | taveta
# Processing Record 26 of Set 7 | taixing
# Processing Record 27 of Set 7 | yeppoon
# Processing Record 28 of Set 7 | xunchang
# Processing Record 29 of Set 7 | mahenge
# Processing Record 30 of Set 7 | ketchikan
# Processing Record 31 of Set 7 | englewood
# Processing Record 32 of Set 7 | sangmelima
# Processing Record 33 of Set 7 | turukhansk
# Processing Record 34 of Set 7 | mporokoso
# Processing Record 35 of Set 7 | beringovskiy
# Processing Record 36 of Set 7 | zemio
# Processing Record 37 of Set 7 | makakilo city
# Processing Record 38 of Set 7 | sobreira
# Processing Record 39 of Set 7 | nerchinskiy zavod
# Processing Record 40 of Set 7 | saint-philippe
# Processing Record 41 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 7 | nhamunda
# Processing Record 45 of Set 7 | natal
# Processing Record 46 of Set 7 | hokitika
# Processing Record 47 of Set 7 | volnovakha
# Processing Record 48 of Set 7 | herat
# Processing Record 49 of Set 7 | ahipara
# Processing Record 50 of Set 7 | dzhida
# Processing Record 1 of Set 8 | cleveland
# Processing Record 2 of Set 8 | isabela
# Processing Record 3 of Set 8 | panaba
# Processing Record 4 of Set 8 | carauari
# Processing Record 5 of Set 8 | kayerkan
# Processing Record 6 of Set 8 | tiksi
# Processing Record 7 of Set 8 | flin flon
# Processing Record 8 of Set 8 | half moon bay
# Processing Record 9 of Set 8 | aasiaat
# Processing Record 10 of Set 8 | chapais
# Processing Record 11 of Set 8 | kanigoro
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | norman wells
# Processing Record 14 of Set 8 | kieta
# Processing Record 15 of Set 8 | richards bay
# Processing Record 16 of Set 8 | rameswaram
# Processing Record 17 of Set 8 | dehloran
# Processing Record 18 of Set 8 | tefe
# Processing Record 19 of Set 8 | urengoy
# Processing Record 20 of Set 8 | kavaratti
# Processing Record 21 of Set 8 | gisborne
# Processing Record 22 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 8 | kloulklubed
# Processing Record 24 of Set 8 | karmana
# City not found. Skipping...
# Processing Record 25 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 8 | reinosa
# Processing Record 27 of Set 8 | dickinson
# Processing Record 28 of Set 8 | tirlyanskiy
# Processing Record 29 of Set 8 | puerto carreno
# Processing Record 30 of Set 8 | miranda
# Processing Record 31 of Set 8 | mayo
# Processing Record 32 of Set 8 | aksarka
# Processing Record 33 of Set 8 | cockburn town
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | lavumisa
# Processing Record 36 of Set 8 | dullewala
# Processing Record 37 of Set 8 | martapura
# Processing Record 38 of Set 8 | horsham
# Processing Record 39 of Set 8 | anshun
# Processing Record 40 of Set 8 | turba
# Processing Record 41 of Set 8 | poole
# Processing Record 42 of Set 8 | phan thiet
# Processing Record 43 of Set 8 | allanmyo
# City not found. Skipping...
# Processing Record 44 of Set 8 | trebic
# Processing Record 45 of Set 8 | pevek
# Processing Record 46 of Set 8 | santa cruz del sur
# Processing Record 47 of Set 8 | samana
# Processing Record 48 of Set 8 | kununurra
# Processing Record 49 of Set 8 | korla
# Processing Record 50 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 1 of Set 9 | woodward
# Processing Record 2 of Set 9 | huilong
# Processing Record 3 of Set 9 | lorengau
# Processing Record 4 of Set 9 | dali
# Processing Record 5 of Set 9 | birin
# Processing Record 6 of Set 9 | cacak
# Processing Record 7 of Set 9 | road town
# Processing Record 8 of Set 9 | lethem
# Processing Record 9 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 10 of Set 9 | cordoba
# Processing Record 11 of Set 9 | torbay
# Processing Record 12 of Set 9 | saint-pierre
# Processing Record 13 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 14 of Set 9 | ailigandi
# Processing Record 15 of Set 9 | tenenkou
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | shingu
# Processing Record 18 of Set 9 | dubuque
# Processing Record 19 of Set 9 | drabiv
# Processing Record 20 of Set 9 | mweka
# Processing Record 21 of Set 9 | geraldton
# Processing Record 22 of Set 9 | balkanabat
# Processing Record 23 of Set 9 | esperance
# Processing Record 24 of Set 9 | gao
# Processing Record 25 of Set 9 | muravlenko
# Processing Record 26 of Set 9 | mecca
# Processing Record 27 of Set 9 | sitka
# Processing Record 28 of Set 9 | xuzhou
# Processing Record 29 of Set 9 | port-de-bouc
# Processing Record 30 of Set 9 | milyutinskaya
# Processing Record 31 of Set 9 | huntingdon
# Processing Record 32 of Set 9 | atbasar
# Processing Record 33 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 34 of Set 9 | manzanillo
# Processing Record 35 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 9 | wadi maliz
# Processing Record 37 of Set 9 | tecpan
# Processing Record 38 of Set 9 | san patricio
# Processing Record 39 of Set 9 | riyadh
# Processing Record 40 of Set 9 | gevrai
# Processing Record 41 of Set 9 | sarakhs
# Processing Record 42 of Set 9 | zhigansk
# Processing Record 43 of Set 9 | solnechnyy
# Processing Record 44 of Set 9 | morondava
# Processing Record 45 of Set 9 | saint-francois
# Processing Record 46 of Set 9 | long beach
# Processing Record 47 of Set 9 | sabang
# Processing Record 48 of Set 9 | yumen
# Processing Record 49 of Set 9 | barberton
# Processing Record 50 of Set 9 | batagay
# Processing Record 1 of Set 10 | carrickmacross
# Processing Record 2 of Set 10 | goderich
# Processing Record 3 of Set 10 | shache
# Processing Record 4 of Set 10 | el vigia
# Processing Record 5 of Set 10 | yomou
# Processing Record 6 of Set 10 | lasa
# Processing Record 7 of Set 10 | laguna
# Processing Record 8 of Set 10 | hofn
# Processing Record 9 of Set 10 | miri
# Processing Record 10 of Set 10 | chiang khong
# Processing Record 11 of Set 10 | karasjok
# Processing Record 12 of Set 10 | miamisburg
# Processing Record 13 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 10 | kenai
# Processing Record 15 of Set 10 | mogadouro
# Processing Record 16 of Set 10 | broken hill
# Processing Record 17 of Set 10 | catamarca
# Processing Record 18 of Set 10 | havoysund
# Processing Record 19 of Set 10 | severo-kurilsk
# Processing Record 20 of Set 10 | faya
# Processing Record 21 of Set 10 | port hedland
# Processing Record 22 of Set 10 | sistranda
# Processing Record 23 of Set 10 | bridlington
# Processing Record 24 of Set 10 | nueva gerona
# Processing Record 25 of Set 10 | san cristobal
# Processing Record 26 of Set 10 | chontalpa
# Processing Record 27 of Set 10 | mao
# Processing Record 28 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 30 of Set 10 | hay river
# Processing Record 31 of Set 10 | fernandina beach
# Processing Record 32 of Set 10 | waipawa
# Processing Record 33 of Set 10 | malanje
# Processing Record 34 of Set 10 | amuntai
# Processing Record 35 of Set 10 | barranca
# Processing Record 36 of Set 10 | coleraine
# Processing Record 37 of Set 10 | cherskiy
# Processing Record 38 of Set 10 | kalianget
# Processing Record 39 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 10 | bilma
# Processing Record 41 of Set 10 | ivesti
# Processing Record 42 of Set 10 | chake chake
# Processing Record 43 of Set 10 | asfi
# Processing Record 44 of Set 10 | quatre cocos
# Processing Record 45 of Set 10 | mujiayingzi
# Processing Record 46 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 10 | warrnambool
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | nuuk
# Processing Record 50 of Set 10 | nambucca heads
# Processing Record 1 of Set 11 | doka
# Processing Record 2 of Set 11 | shitanjing
# Processing Record 3 of Set 11 | moju
# Processing Record 4 of Set 11 | peniche
# Processing Record 5 of Set 11 | peoria
# Processing Record 6 of Set 11 | kamaishi
# Processing Record 7 of Set 11 | tahta
# Processing Record 8 of Set 11 | kupang
# Processing Record 9 of Set 11 | taizhou
# Processing Record 10 of Set 11 | kamojima
# Processing Record 11 of Set 11 | temerloh
# Processing Record 12 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 11 | srandakan
# Processing Record 14 of Set 11 | alianca
# City not found. Skipping...
# Processing Record 15 of Set 11 | starominskaya
# Processing Record 16 of Set 11 | harjavalta
# Processing Record 17 of Set 11 | gashua
# Processing Record 18 of Set 11 | paralimni
# Processing Record 19 of Set 11 | majene
# Processing Record 20 of Set 11 | nhulunbuy
# Processing Record 21 of Set 11 | saint-augustin
# Processing Record 22 of Set 11 | tulum
# Processing Record 23 of Set 11 | hutang
# Processing Record 24 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 11 | altamira
# Processing Record 26 of Set 11 | bandarbeyla
# Processing Record 27 of Set 11 | petrovsk
# Processing Record 28 of Set 11 | mwaya
# Processing Record 29 of Set 11 | masumbwe
# Processing Record 30 of Set 11 | laukaa
# Processing Record 31 of Set 11 | tigil
# Processing Record 32 of Set 11 | orshanka
# Processing Record 33 of Set 11 | parbhani
# Processing Record 34 of Set 11 | ahuimanu
# Processing Record 35 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 36 of Set 11 | singaraja
# Processing Record 37 of Set 11 | leshan
# Processing Record 38 of Set 11 | waddan
# Processing Record 39 of Set 11 | altus
# Processing Record 40 of Set 11 | timra
# Processing Record 41 of Set 11 | magugu
# Processing Record 42 of Set 11 | carnot
# Processing Record 43 of Set 11 | atar
# Processing Record 44 of Set 11 | pedernales
# Processing Record 45 of Set 11 | nikolsk
# Processing Record 46 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 47 of Set 11 | terrace bay
# Processing Record 48 of Set 11 | adrar
# Processing Record 49 of Set 11 | sungaipenuh
# Processing Record 50 of Set 11 | arlit
# Processing Record 1 of Set 12 | omsukchan
# Processing Record 2 of Set 12 | mondlo
# Processing Record 3 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 12 | gamba
# Processing Record 5 of Set 12 | matagami
# Processing Record 6 of Set 12 | sucha beskidzka
# Processing Record 7 of Set 12 | praia da vitoria
# Processing Record 8 of Set 12 | maragogi
# Processing Record 9 of Set 12 | kirakira
# Processing Record 10 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 12 | salta
# Processing Record 12 of Set 12 | kinablangan
# Processing Record 13 of Set 12 | kendari
# Processing Record 14 of Set 12 | luganville
# Processing Record 15 of Set 12 | nakhon thai
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | ionia
# Processing Record 18 of Set 12 | tongren
# Processing Record 19 of Set 12 | flinders
# Processing Record 20 of Set 12 | salym
# Processing Record 21 of Set 12 | trinidad
# Processing Record 22 of Set 12 | san andres
# Processing Record 23 of Set 12 | vanavara
# Processing Record 24 of Set 12 | rosetta
# Processing Record 25 of Set 12 | acapulco
# Processing Record 26 of Set 12 | hurghada
# Processing Record 27 of Set 12 | zaraza
# Processing Record 28 of Set 12 | voyvozh
# Processing Record 29 of Set 12 | chapleau
# Processing Record 30 of Set 12 | itacoatiara
# Processing Record 31 of Set 12 | sturgeon bay
# Processing Record 32 of Set 12 | jinchang
# Processing Record 33 of Set 12 | the pas
# Processing Record 34 of Set 12 | fort nelson
# Processing Record 35 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 12 | lompoc
# Processing Record 38 of Set 12 | boguchany
# Processing Record 39 of Set 12 | amarante do maranhao
# Processing Record 40 of Set 12 | guarapari
# Processing Record 41 of Set 12 | ilhabela
# Processing Record 42 of Set 12 | ambilobe
# Processing Record 43 of Set 12 | almaty
# Processing Record 44 of Set 12 | havre
# Processing Record 45 of Set 12 | mareeba
# Processing Record 46 of Set 12 | kawalu
# Processing Record 47 of Set 12 | victoria point
# Processing Record 48 of Set 12 | saintes
# Processing Record 49 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 12 | taoudenni
# Processing Record 1 of Set 13 | nouadhibou
# Processing Record 2 of Set 13 | novi sanzhary
# Processing Record 3 of Set 13 | west bay
# Processing Record 4 of Set 13 | mapiripan
# Processing Record 5 of Set 13 | puerto pinasco
# City not found. Skipping...
# Processing Record 6 of Set 13 | concarneau
# Processing Record 7 of Set 13 | miles city
# Processing Record 8 of Set 13 | imbituba
# Processing Record 9 of Set 13 | berlin
# Processing Record 10 of Set 13 | nayoro
# Processing Record 11 of Set 13 | lydenburg
# Processing Record 12 of Set 13 | buraydah
# Processing Record 13 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 13 | canon city
# Processing Record 15 of Set 13 | atambua
# Processing Record 16 of Set 13 | iqaluit
# Processing Record 17 of Set 13 | burns lake
# Processing Record 18 of Set 13 | prince rupert
# Processing Record 19 of Set 13 | benalla
# Processing Record 20 of Set 13 | vila franca do campo
# Processing Record 21 of Set 13 | kabansk
# Processing Record 22 of Set 13 | voloshka
# Processing Record 23 of Set 13 | port pirie
# Processing Record 24 of Set 13 | nazilli
# Processing Record 25 of Set 13 | pandan
# Processing Record 26 of Set 13 | arnold
# Processing Record 27 of Set 13 | quelimane
# Processing Record 28 of Set 13 | cedar city
# Processing Record 29 of Set 13 | kilingi-nomme
# Processing Record 30 of Set 13 | ino
# Processing Record 31 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 13 | padang
# Processing Record 33 of Set 13 | jatiroto
# Processing Record 34 of Set 13 | margate
# Processing Record 35 of Set 13 | rio verde de mato grosso
# Processing Record 36 of Set 13 | raymondville
# Processing Record 37 of Set 13 | bosaso
# Processing Record 38 of Set 13 | pilar
# Processing Record 39 of Set 13 | haileybury
# Processing Record 40 of Set 13 | onega
# Processing Record 41 of Set 13 | inuvik
# Processing Record 42 of Set 13 | xining
# Processing Record 43 of Set 13 | maarianhamina
# Processing Record 44 of Set 13 | goba
# Processing Record 45 of Set 13 | colac
# Processing Record 46 of Set 13 | changli
# Processing Record 47 of Set 13 | cerritos
# Processing Record 48 of Set 13 | mucurapo
# Processing Record 49 of Set 13 | eirunepe
# Processing Record 50 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 14 | verkhoyansk
# ------------------------------------------------
# Data Retrieval Complete
# ------------------------------------------------

# %%
len(lat)
len(temp)
# Out:
# 651

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df  = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})
# Show Record Count
city_data_df .count()
# Out:
# City          651
# Lat           596
# lng           596
# Max Temp      596
# Humidity      596
# Cloudiness    596
# Wind Speed    596
# Country       596
# Date          596
# dtype: int64

# %%
city_data_df .head()
# Out:
#            City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto ayora  -0.7393  -90.3518     74.55      95.0        14.0
# 1         airai  -8.9266  125.4092     68.38      82.0       100.0
# 2      hermanus -34.4187   19.2345     62.65      57.0         7.0
# 3     tilichiki  60.4667  166.1000     11.12      80.0       100.0
# 4        hobart -42.8794  147.3294     82.22      63.0        95.0
#
#    Wind Speed Country          Date
# 0        5.17      EC  1.674625e+09
# 1        2.26      TL  1.674625e+09
# 2        8.37      ZA  1.674625e+09
# 3       10.80      RU  1.674625e+09
# 4        1.01      AU  1.674625e+09

# %%
 #Export the city data into a .csv file.
city_data_df.to_csv("./output_data/cities_w.csv", index=False)

#Load the CSV file into a Pandas DataFrame
city_data_df= pd.read_csv("./output_data/cities_w.csv")

# Display sample data
city_data_df.head()
# Out:
#            City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto ayora  -0.7393  -90.3518     74.55      95.0        14.0
# 1         airai  -8.9266  125.4092     68.38      82.0       100.0
# 2      hermanus -34.4187   19.2345     62.65      57.0         7.0
# 3     tilichiki  60.4667  166.1000     11.12      80.0       100.0
# 4        hobart -42.8794  147.3294     82.22      63.0        95.0
#
#    Wind Speed Country          Date
# 0        5.17      EC  1.674625e+09
# 1        2.26      TL  1.674625e+09
# 2        8.37      ZA  1.674625e+09
# 3       10.80      RU  1.674625e+09
# 4        1.01      AU  1.674625e+09

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(7,5))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs Max Temperature")
plt.grid()
plt.savefig("./output_data/latitude_vs_temperature.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(7, 5))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity')
plt.grid()
plt.savefig("./output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(7, 5))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness')
plt.grid()
plt.savefig("./output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(7, 5))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(%)')
plt.title(f'City Latitude vs Wind Speed')
plt.grid()
plt.savefig("./output_data/latitude_vs_Wind Speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
 # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(7,5))
    plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
    plt.xlabel(x_label,fontsize = 7)
    plt.ylabel(y_label,fontsize = 7)
    if ylim is not None:
        plt.ylim(0, ylim)
    
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label}",fontsize = 10)
    plt.annotate(line_eq,xy=(10, 50),fontsize=10,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-50, 40),fontsize=10,xycoords='data',xytext=(0.4, 0.3), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(10, 25),fontsize=10,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
   
 # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    return plt.plot(x_values,regress_values,"r-")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 3      tilichiki  60.4667  166.1000     11.12      80.0       100.0
# 5     butaritari   3.0707  172.7902     81.30      79.0        91.0
# 6   ponta do sol  32.6667  -17.1000     59.63      50.0         5.0
# 9          kapaa  22.0752 -159.3190     75.18      84.0        75.0
# 10   brownsville  25.9018  -97.4975     62.96      60.0       100.0
#
#     Wind Speed Country          Date
# 3        10.80      RU  1.674625e+09
# 5        18.10      KI  1.674625e+09
# 6         9.46      PT  1.674625e+09
# 9        16.11      US  1.674625e+09
# 10        5.75      US  1.674625e+09

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#            City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto ayora  -0.7393  -90.3518     74.55      95.0        14.0
# 1         airai  -8.9266  125.4092     68.38      82.0       100.0
# 2      hermanus -34.4187   19.2345     62.65      57.0         7.0
# 4        hobart -42.8794  147.3294     82.22      63.0        95.0
# 7       mlonggo  -6.5333  110.7000     82.36      76.0       100.0
#
#    Wind Speed Country          Date
# 0        5.17      EC  1.674625e+09
# 1        2.26      TL  1.674625e+09
# 2        8.37      ZA  1.674625e+09
# 4        1.01      AU  1.674625e+09
# 7       11.63      ID  1.674625e+09

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))
plt.savefig("./output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.7047800315860323
# The correlation between both factors is -0.84

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Lat", "Max Temp (F)", "Southern",(0, 0))
plt.savefig("./output_data/Southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.16263412019181261
# The correlation between both factors is 0.4

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Lat", "Humidity", "Northern",(0, 0))
plt.savefig("./output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.14455851020527888
# The correlation between both factors is 0.38

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Lat", "Humidity", "Southern",(0, 0))
plt.savefig("./output_data/Southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.23400697489691477
# The correlation between both factors is 0.48

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Lat", "Cloudiness", "Northern",(0, 0))
plt.savefig("./output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.09736849754624462
# The correlation between both factors is 0.31

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Lat", "Cloudiness", "Southern",(0, 0))
plt.savefig("./output_data/Southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.20374744177282988
# The correlation between both factors is 0.45

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Lat", "Wind Speed", "Northern",(0, 0))
plt.savefig("./output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.025824790750737677
# The correlation between both factors is 0.16

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Lat", "Wind Speed", "Southern",(0, 0))
plt.savefig("./output_data/Southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.10819098156250795
# The correlation between both factors is -0.33

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
